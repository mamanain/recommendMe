# %%
import vk
import pandas as pd
import random
import time

# %%
friends = vk.get_friends("1")
movies = []
count = 0

for friend in friends: 
    if count >= 5:
        break
    info = vk.get_users_info([friend])
    if "movies" in info[str(friend)].keys() and info[str(friend)]["movies"] != "":
        movies.append(info[str(friend)]["movies"])
        count += 1

# %%
def split_movies(movies):
    mov = []
    for friend_movies in movies:
        l = friend_movies.split(",")
        for x in l:
            mov.append(x)
    return mov

def get_close_movies(id):
    id = str(id)
    movies = []
    
    ui = vk.get_users_info([id])
    
    #Add users movies
    
    if "movies" in ui[id].keys() and ui[id]["movies"] != "":
        m = ui[id]["movies"].split(",")
        for x in m:
            movies.append(x)
    
    #Add friends movies
    
    
    return movies

# %%
get_close_movies(4535)
# Out:
# []

# %%
from sklearn.externals import joblib

# %%
def get_data(id, n, min_num_of_movies=3):
    movies = pd.Series()
    last_id = 0
    index = 0
    count = 0
    
    while movies.size < n:
        
        
        f = vk.get_friends(str(id))

        friends = []
        for x in f:
            friends.append(str(x))
            
        for friend in friends:
            if movies.size >= n:
                break
            
            try:
                user_info = vk.get_users_info([friend])

                if count == 100:
                    print("pause")
                    time.sleep(1)
                    count = 0
                else:
                    count += 1

                if ("movies" in user_info[friend].keys() 
                    and len(user_info[friend]["movies"]) >= min_num_of_movies
                    and not friend in movies.keys()
                    and len(friends) >= 5):
                    if index % 20 == 0:
                        joblib.dump(movies, filename="movies1", compress=9)
                    movies.set_value(index, user_info[friend]["movies"].split(","))
                    index += 1
                    print(friend)
            except:
                pass
        print("Index: " + str(index))
        print("Id: " + str(id))
        print("Last id: " + str(last_id))
        if movies.size < n:
            last_id = id
            while True: 
                ind = random.randint(0, len(friends))
                if (len(vk.get_friends(friends[ind])) != 0
                    or last_id != friends[ind]):
                    id = friends[ind]
                    break
            
    return movies

# %%
_train_data = get_data(1, 1000)
# Out:
# 54
# 193
# 194
# 237
# 1634
# 2745
# 3148
# 3420
# 4016
# 4231
# 4766
# 4923
# 5333
# 5524
# 6099
# 6413
# 7990
# 11191
# 13033
# 13557
# 15221
# 15496
# 15740
# 16990
# 36555
# 43857
# 59628
# 66559
# 83813
# 88111
# 88324
# 93588
# 94627
# 95602
# 122376
# 172823
# 180083
# 184760
# 213623
# 248780
# 465975
# 466034
# 466934
# 517780
# 530053
# 533796
# 551225
# 638391
# 788746
# 820969
# 823293
# 833249
# 859412
# 896232
# 904047
# 938889
# 1120176
# 1235202
# 1549462
# 1666872
# 1708231
# 1826463
# 1856843
# 1987761
# 2080736
# 2426092
# 2452501
# 2562137
# 2677959
# 3092814
# 3240642
# 3883830
# 3930504
# 4029573
# 4926666
# 5005272
# 5257328
# 6125743
# 7235762
# 8611282
# 9078753
# 9522403
# 10038567
# 11032244
# 12102180
# 12370373
# 12695418
# 12992757
# 13963740
# 15907326
# 15915916
# 16350900
# 18425009
# 19187792
# 19605469
# 20020126
# 33709966
# 41110630
# 41623786
# 49286014
# 51825278
Network is unreachable
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# /home/mdm/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     577                                                   body=body, headers=headers,
# --> 578                                                   chunked=chunked)
#     579
#
# /home/mdm/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     361         else:
# --> 362             conn.request(method, url, **httplib_request_kw)
#     363
#
# /home/mdm/anaconda3/lib/python3.5/http/client.py in request(self, method, url, body, headers)
#    1105         """Send a complete request to the server."""
# -> 1106         self._send_request(method, url, body, headers)
#    1107
#
# /home/mdm/anaconda3/lib/python3.5/http/client.py in _send_request(self, method, url, body, headers)
#    1150             body = _encode(body, 'body')
# -> 1151         self.endheaders(body)
#    1152
#
# /home/mdm/anaconda3/lib/python3.5/http/client.py in endheaders(self, message_body)
#    1101             raise CannotSendHeader()
# -> 1102         self._send_output(message_body)
#    1103
#
# /home/mdm/anaconda3/lib/python3.5/http/client.py in _send_output(self, message_body)
#     933
# --> 934         self.send(msg)
#     935         if message_body is not None:
#
# /home/mdm/anaconda3/lib/python3.5/http/client.py in send(self, data)
#     876             if self.auto_open:
# --> 877                 self.connect()
#     878             else:
#
# /home/mdm/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/connection.py in connect(self)
#     166     def connect(self):
# --> 167         conn = self._new_conn()
#     168         self._prepare_conn(conn)
#
# /home/mdm/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/connection.py in _new_conn(self)
#     150             raise NewConnectionError(
# --> 151                 self, "Failed to establish a new connection: %s" % e)
#     152
#
# NewConnectionError: <requests.packages.urllib3.connection.HTTPConnection object at 0x7f5611a0e198>: Failed to establish a new connection: [Errno 101] Network is unreachable
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# /home/mdm/anaconda3/lib/python3.5/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     402                     retries=self.max_retries,
# --> 403                     timeout=timeout
#     404                 )
#
# /home/mdm/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     622             retries = retries.increment(method, url, error=e, _pool=self,
# --> 623                                         _stacktrace=sys.exc_info()[2])
#     624             retries.sleep()
#
# /home/mdm/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     280         if new_retry.is_exhausted():
# --> 281             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     282
#
# MaxRetryError: HTTPConnectionPool(host='api.vk.com', port=80): Max retries exceeded with url: /method/users.get (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f5611a0e198>: Failed to establish a new connection: [Errno 101] Network is unreachable',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-123-5481d6f88311> in <module>()
# ----> 1 _train_data = get_data(1, 1000)
#
# <ipython-input-121-a8fddc64cc7e> in get_data(id, n, min_num_of_movies)
#      18                 break
#      19
# ---> 20             user_info = vk.get_users_info([friend])
#      21
#      22             if count == 1000:
#
# /home/mdm/Documents/recommendMe/vk.py in get_users_info(users_list)
#      59     while start < len(users_list):
#      60         request_ids = ",".join([str(id) for id in users_list[start:start+batch_size]])
# ---> 61         data = base_request("users.get", [("fields", fields), ("user_ids", request_ids)], True, timeout=5)
#      62         for item in data:
#      63             result[str(item['uid'])] = item
#
# /home/mdm/Documents/recommendMe/vk.py in base_request(method, params, print_error, timeout)
#      20     while True:
#      21         try:
# ---> 22             response = requests.post(url, data=dict(params), timeout=timeout)
#      23             break
#      24         except ReadTimeout:
#
# /home/mdm/anaconda3/lib/python3.5/site-packages/requests/api.py in post(url, data, json, **kwargs)
#     109     """
#     110
# --> 111     return request('post', url, data=data, json=json, **kwargs)
#     112
#     113
#
# /home/mdm/anaconda3/lib/python3.5/site-packages/requests/api.py in request(method, url, **kwargs)
#      55     # cases, and look like a memory leak in others.
#      56     with sessions.Session() as session:
# ---> 57         return session.request(method=method, url=url, **kwargs)
#      58
#      59
#
# /home/mdm/anaconda3/lib/python3.5/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     473         }
#     474         send_kwargs.update(settings)
# --> 475         resp = self.send(prep, **send_kwargs)
#     476
#     477         return resp
#
# /home/mdm/anaconda3/lib/python3.5/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     583
#     584         # Send the request
# --> 585         r = adapter.send(request, **kwargs)
#     586
#     587         # Total elapsed time of the request (approximately)
#
# /home/mdm/anaconda3/lib/python3.5/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     465                 raise ProxyError(e, request=request)
#     466
# --> 467             raise ConnectionError(e, request=request)
#     468
#     469         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='api.vk.com', port=80): Max retries exceeded with url: /method/users.get (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f5611a0e198>: Failed to establish a new connection: [Errno 101] Network is unreachable',))

# %%
some_shit = get_data(2, 100000)
# Out:
# 1
# 447
# 2745
# Index: 3
# Id: 2
# Last id: 0
# 287337
# 1096802
# 1396638
# 4214368
# pause
# Index: 7
# Id: 100000
# Last id: 2
# 2745
# 3420
# 3422
# 13033
# 15485
# 20550
# 21835
# 59628
# 160693
# 172823
# 176557
# 186814
# pause
# 416231
# 517780
# 537049
# 638391
# 690765
# 896232
# 940661
# 1004736
# pause
# 1324639
# 1376453
# 1708231
# 2097527
# 2233374
# 2300159
# 2308551
# 2922627
# 4628820
# pause
# 19187792
# 19772489
# 23961121
# 41190042
# pause
# 56545441
# 62496351
# 338417957
# Index: 43
# Id: 2014477
# Last id: 100000
# 59628
# pause
# 14258587
# 23870820
# 30361555
# 36344592
# Index: 48
# Id: 9719828
# Last id: 2014477
# 2745
# 3420
# pause
# 59628
# 117104
# 160693
# 172823
# 176557
# 276959
# 381542
# 935267
# 940661
# 1306756
# 1324639
# 1657511
# 2482012
# pause
# 5430281
# 7114112
# 18702205
# 19187792
# 43867259
# 144154870
# 182251896
# pause
# Index: 70
# Id: 190093965
# Last id: 9719828
# 160693
# 176557
# 276959
# 880725
# 1370097
# 1657511
# 2475145
# 4344861
# pause
# 8348188
# 9017078
# 10584283
# 12418699
# 18135277
# 19279228
# 22177219
# 26958833
# 31727207
# pause
# 43867259
# 44035696
# 51370885
# 53113934
# 162121620
# 182408484
# 202520310
# Index: 94
# Id: 2283212
# Last id: 190093965
# pause
# 307368
# 412920
# 568357
# 704056
# 1035512
# 1506125
# 1661069
# 1991425
# 2607091
# 3458811
# 5295215
# 5715183
# 13719439
# 16354345
# 16434629
# 20127818
# pause
# 40800069
# 92850262
# 144360548
# 147831937
# 175319176
# 202569258
# 208403411
# 213674265
# pause
# 251102331
# 259167810
# 270106048
# 350198356
# Index: 122
# Id: 3733295
# Last id: 2283212
# 90059
# 13674837
# 17323200
# 17411110
# 29300944
# 39203038
# pause
# 78120825
# 106507952
# 152406302
# 159335501
# 197702717
# 200458561
# 200686557
# pause
# 217961320
# 236118856
# 241843677
# 297168907
# 2496189
# 2759902
# 2891684
# 3536449
# 3931118
# 3947129
# 3964970
# 5129054
# 7755956
# pause
# 8699672
# 9030060
# 11516746
# 12850518
# 13179824
# 17080251
# 23802553
# 28513985
# pause
# 31978165
# 63983304
# 67840563
# 71640629
# 89829468
# 101776915
# 118835532
# 136781501
# pause
# 144901821
# 152199880
# 164301604
# 180583093
# 190482092
# 190777749
# 237273480
# 272014777
# 277414446
# Index: 1089
# Id: 1893141
# Last id: 930222
# pause
# 930222
# 1331546
# 1399325
# 1600294
# 2032364
# 2162395
# 2574843
# pause
# 4175361
# 13265599
# 22124637
# 24800463
# 25670740
# 33266398
# 53810464
# 54575475
# 57859320
# 85076507
# 142224268
# 187174903
# pause
# Index: 1108
# Id: 313296
# Last id: 1893141
# Index: 1108
# Id: 315343334
# Last id: 313296
# 2754227
# 63639138
# 213500402
# 255613871
# pause
# 328173787
# 345972175
# Index: 1114
# Id: 285717889
# Last id: 315343334
# 213500402
# 228394938
# pause
# Index: 1116
# Id: 311915888
# Last id: 285717889
# 139901320
# 217219876
# 254203367
# 262853438
# pause
# 279419202
# 340951379
# 374248562
# Index: 1123
# Id: 315974522
# Last id: 311915888
# 76255250
# 79399047
# 139901320
# 188053742
# pause
# 217219876
# 374248562
# Index: 1129
# Id: 248760637
# Last id: 315974522
# 220921277
# pause
# Index: 1130
# Id: 334991429
# Last id: 248760637
# Index: 1130
# Id: 298123545
# Last id: 334991429
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-145-43e636d0570a> in <module>()
# ----> 1 some_shit = get_data(2, 100000)
#
# <ipython-input-144-f88ee188fb9a> in get_data(id, n, min_num_of_movies)
#      46             while True:
#      47                 ind = random.randint(0, len(friends))
# ---> 48                 if (len(vk.get_friends(friends[ind])) != 0
#      49                     or last_id != friends[ind]):
#      50                     id = friends[ind]
#
# IndexError: list index out of range

# %%
a = joblib.load("movies")

# %%
a
# Out:
# 0      [Мертвец,  Бойцовский клуб,  Королевская битва...
# 1      [Vanilla Sky,  I Robot,  Idiocracy,  Lock,  st...
# 2       [«Карты,  деньги,  два ствола»,  и много других]
# 3      [Rosencrantz and Guildenstern are dead,  весте...
# 4      ["О чем говорят мужчины",  "Мистер и миссис См...
# 5      [Ванильное небо,  Дом у озера,  Двухсотлетний ...
# 6      [Малхолланд Драйв,  Человек которого не было, ...
# 7                                          [Эквилибриум]
# 8      [Человек с киноаппаратом,  Modern Times,  The ...
# 9      [Бойцовский клуб,  Матрица,  Плезентвиль,  Тра...
# 10     [The Matrix,  Ocean's Eleven,  Guy Ritchie,  F...
# 11     [Thomas Crown Affair,  Schindler's List,  Godf...
# 12          [День Сурка,  Трасса 60,  Побег из Шоушенка]
# 13                         [The Game (by David Fincher)]
# 14     [Devil's advocate,  Valhalla rising,  Revenger...
# 15                            [Ferris Bueller's Day Off]
# 16     [Красота по-американски,  Стиляги,  Across the...
# 17                      [Профессионал,  Назад в Будущее]
# 18                 [The Curious Case of Benjamin Button]
# 19     [Даун Хаус,  Шапито Шоу,  Иваново Детство,  Ка...
# 20                                           [Тарантино]
# 21     [Бойцовский клуб,  Аризонская мечта,  Сталкер,...
# 22                                          [Hot Shots!]
# 23     [Casablanca,  The Matrix,  North By Northwest,...
# 24     [Все фильмы Эдриана Лайна. Последние фильмы с ...
# 25     [La Sortie de l'usine Lumière à Lyon,  ,  l'Ar...
# 26     [Fight Club,  Cruel Intentions,  Евротур,  Кри...
# 27     [South Park,  Тот Самый Мюнхгаузен,  Yellow Su...
# 28       [http://www.kinopoisk.ru/level/79/user/995497/]
# 29     [Назад в будущее,  Призрак,  Грязные танцы,  Ш...
#                              ...
# 470                                              [&#13;]
# 471                                       [Форрест Гамп]
# 472    [2012,  Письма к Джульетте,  &amp;quot;Очень с...
# 473    [Неудержимые,  Человек паук,  Трансформеры,  M...
# 474    [!!фантастика,  фентези,  исторические,  прикл...
# 475       [Ванильное небо,  Любовь морковь,  Шаг вперёд]
# 476                                  [1-9 фильмы Наруто]
# 477    [Закрытая Школа,  велеколепный век,  :Кёсем су...
# 478                                           [форсаж 6]
# 479    [В погоне за счастьем,  семь жизней,  несломле...
# 480    [Брат,  Брат 2,  Неудержимые,  Смертельная гон...
# 481    [Ужас,  Триллер,  Комедия,  Фантастика,  ну а ...
# 482    [Deadpool,  Oblivion,  A Walk Among the Tombst...
# 483    [Пила 1-7,  Властелин Колец,  1-3 13 грехов,  ...
# 484                                        [Воин (2011)]
# 485                                              [разни]
# 486                                          [Рыжий пес]
# 487          [Десантура,  9-рота,  Грозовые ворота! ! !]
# 488    [Гарри Поттер,  Железный человек,  Мумия,  Ноч...
# 489    [____________________________________§¶¶¶§____...
# 490    [Фантастика,  Ужасы,  Мелодрамы,  Комедии.По н...
# 491                                                [Нет]
# 492                        [Ужасы,  комедии,  детективы]
# 493                                      [Фактор страха]
# 494                                            [смешные]
# 495    [биографический вестерн военный детектив докум...
# 496                                     [он снова здесь]
# 497                          [комедий,  ужасы,  боевики]
# 498                                              [ужасы]
# 499                                         [Их много:р]
# dtype: object

# %%
joblib.dump(train_data, filename="data", compress=9)
# Out:
# ['data']

# %%
data = joblib.load("data")

# %%
data
# Out:
# 0     [Мертвец,  Бойцовский клуб,  Королевская битва...
# 1     [Vanilla Sky,  I Robot,  Idiocracy,  Lock,  st...
# 2      [«Карты,  деньги,  два ствола»,  и много других]
# 3     [Rosencrantz and Guildenstern are dead,  весте...
# 4     ["О чем говорят мужчины",  "Мистер и миссис См...
# 5     [Ванильное небо,  Дом у озера,  Двухсотлетний ...
# 6     [Малхолланд Драйв,  Человек которого не было, ...
# 7                                         [Эквилибриум]
# 8     [Человек с киноаппаратом,  Modern Times,  The ...
# 9     [Бойцовский клуб,  Матрица,  Плезентвиль,  Тра...
# 10    [The Matrix,  Ocean's Eleven,  Guy Ritchie,  F...
# 11    [Thomas Crown Affair,  Schindler's List,  Godf...
# 12         [День Сурка,  Трасса 60,  Побег из Шоушенка]
# 13                        [The Game (by David Fincher)]
# 14    [Devil's advocate,  Valhalla rising,  Revenger...
# 15                           [Ferris Bueller's Day Off]
# 16    [Красота по-американски,  Стиляги,  Across the...
# 17                     [Профессионал,  Назад в Будущее]
# 18                [The Curious Case of Benjamin Button]
# 19    [Даун Хаус,  Шапито Шоу,  Иваново Детство,  Ка...
# 20                                          [Тарантино]
# 21    [Бойцовский клуб,  Аризонская мечта,  Сталкер,...
# 22                                         [Hot Shots!]
# 23    [Casablanca,  The Matrix,  North By Northwest,...
# 24    [Все фильмы Эдриана Лайна. Последние фильмы с ...
# 25    [La Sortie de l'usine Lumière à Lyon,  ,  l'Ar...
# 26    [Fight Club,  Cruel Intentions,  Евротур,  Кри...
# 27    [South Park,  Тот Самый Мюнхгаузен,  Yellow Su...
# 28      [http://www.kinopoisk.ru/level/79/user/995497/]
# 29    [Назад в будущее,  Призрак,  Грязные танцы,  Ш...
#                             ...
# 70    [Бойцовский Клуб,  V значит Вендетта,  Влюбись...
# 71             [Mr Nobody (на февраль 2011),  Рассказы]
# 72    [In Bruges,  Into The Wild,  There Will Be Blood]
# 73                             [см. альбом "КИНОПОИСК"]
# 74        [Сериал "Визитеры" и сериал "Тайны Смолвиля"]
# 75    [Waking Life,  Amelie,  Весна-лето-осень-зима,...
# 76    ["Гудзонский ястреб" на языке оригинала,  и ещ...
# 77    [The Good The Bad and The Ugly,  Casablanca,  ...
# 78    [http://bananastreet.ru/djmaniak\nwww.luxury-m...
# 79    ["Соблазн",  "Основной  инстинкт",  "Неудержим...
# 80                 [The Sting/Афера,  God Father 1-2-3]
# 81    [Английский пациент,  Gia,  Сладкий Ноябрь,  С...
# 82                         [99 франков,  Трон (первый)]
# 83    [Однажды,  День сурка,  Проблеск гениальности,...
# 84    [Law Abiding Citizen,  Le Fabuleux destin d'Am...
# 85    ["Сталкер" А. Тарковского,  "Полеты во сне и н...
# 86                                    [Властелин Колец]
# 87    [Фильмы Рязанова,  Игры разума,  Гладиатор,  Л...
# 88    [Планета Ка-Пэкс. Форрест Гамп.Звуки шума. Дон...
# 89                                  [АССА,  Fallen art]
# 90                     [Interstate 60,  Legally Blonde]
# 91    [Blow-up,  В прошлом году в Мариенбаде,  Книги...
# 92                          [С бюджетом больше 10 M $.]
# 93    [«Зелёная миля»,  «Матрица»,  «Ангелы и демоны...
# 94    [Песня для изгоя/Song for a raggy boy(2003),  ...
# 95    [Люблю фильмы Тенгиза Абуладзе,  Стивена Спилб...
# 96    ["Трудности перевода",  "Даун Хаус",  "Три ист...
# 97          [Зеленая миля,  Книга Илая,  Запах женщины]
# 98    [Saving Private Ryan,  City of Angels,  Superm...
# 99    [Слоган,  Унесенные ветром,  Завтрак у Тиффани...
# dtype: object

# %%
train_data = a

# %%
def get_unique_movies(data):
    unique_movies = pd.Series()
    index = 0
    for movies in data:
        for movie in movies:
            if not movie in unique_movies:
                unique_movies.set_value(index, movie)
                index += 1
    return unique_movies

# %%
len(unique_movies)
# Out:
# 2978

# %%
from scipy.sparse import csr_matrix
from numpy import array

# %%
unique_movies[unique_movies == "Vanilla Sky"].index[0]
# Out:
# 11

# %%
def construct_matrix(data, unique_movies):
    row = []
    column = []

    for user in data.keys():
        for movie in data[user]:
            row.append(user)
            column.append(unique_movies[unique_movies == movie].index[0])
    data = [1 for x in range(len(row))]
    movies_matrix = csr_matrix((data, (row, column)), \
                               shape=(len(data), len(unique_movies)))
    return movies_matrix

# %%
row = []
column = []

for user in train_data.keys():
    for movie in train_data[user]:
        row.append(user)
        column.append(unique_movies[unique_movies == movie].index[0])

# %%
data = [1 for x in range(len(row))]
movies_matrix = csr_matrix((data, (row, column)), shape=(len(train_data), len(unique_movies)))

# %%
b = joblib.load("movies1")

# %%
b
# Out:
# 0                                          [12 Angry Men]
# 1       ["Зеленая миля",  "Инопланетянин",  "Искусстве...
# 2       [Ванильное небо,  Дом у озера,  Двухсотлетний ...
# 3                                       [только не ужасы]
# 4                     [Зеленая миля,  Побег из Шоу Шенка]
# 5                                         [не индийские)]
# 6                                        [Любимые фильмы]
# 7       [Ванильное небо,  Дом у озера,  Двухсотлетний ...
# 8                                           [Эквилибриум]
# 9       ["Сломанные цветы" Джим Джармуш,  "Поговори с ...
# 10                  [The Curious Case of Benjamin Button]
# 11      [Дом у озера,  Зелёная миля,  Сладкий ноябрь, ...
# 12      [Pixar,  Рязанов+Брагинский,  московские 50-60...
# 13      [Форест Гамп,  Военный ныряльщик,  Ирония судь...
# 14      [Fight Club,  Cruel Intentions,  Евротур,  Кри...
# 15      [Крупная Рыба,  Трасса 60,  Пятый Элемент,  Шр...
# 16      [Афоня,  Серьезный человек,  сериал Лейтенант ...
# 17      [Скала,  Клик,  Достучаться до небес..м много ...
# 18                                          [Кошачий суп]
# 19      [Угнать за 60 секунд,  пока я не сыграл в ящик...
# 20                                     [Withnail &amp; I]
# 21      [кофе и сигареты,  голова в облаках,  жизнь ил...
# 22      [Престиж,  Лицо со шрамом,  Три икса,  Бэтмэн ...
# 23                                    [Про двойную жизнь]
# 24      [Железный человек,  Матрица,  Бойцовский клуб,...
# 25      [Багровые реки 1,  Багровые реки 2,  Трансформ...
# 26      [Бойцовский клуб,  Я робот,  Зеленая миля,  Се...
# 27                 [http://www.kinopoisk.ru/user/763060/]
# 28      [Любимый фильм тот,  который я снимаю на протя...
# 29      [Добрые,  типа советских,  сейчас таких не сни...
#                               ...
# 1090                         [вуншпунш  морской аквариум]
# 1091    [Казино Рояль,  Грязные танцы 2,  Пираты Кариб...
# 1092    [унесённые ветром,  мост ватерлоо,  Дрянные де...
# 1093    [Untitled Chronicles of Riddick Sequel (Хроник...
# 1094    ["Жизнь прекрасна",  "Список Шиндлера",  "Нача...
# 1095    [фильмы с Луи де Фюнесом,  Реальная любовь,  с...
# 1096    [Заводной Апельсин,  Детки,  Кен Парк,  Чёрная...
# 1097                           [Властелин колец,  Аватар]
# 1098    ["Шаг вперед",  "шаг вперёд2",  "слепая месть"...
# 1099    ["Идеальный побег2",  "Эффект бабочки 1,  2,  ...
# 1100    [11 (12,  13) друзей Оушена,  Форест Гамп,  Пл...
# 1101                                  [Призрачный гонщик]
# 1102                  [унесенные ветром,  дневник памяти]
# 1103                                         [разные )))]
# 1104    [................................................
# 1105                        [фанатик,  форсаж,  7 жизней]
# 1106    [▄▄Американская история Х,  Апокалипсис сегодн...
# 1107                                           [классика]
# 1108    [star wars,  назад в будущее,  амели,  эквилиб...
# 1109                                 [Которые понравятся]
# 1110                                 [Вам лучше не знать]
# 1111               [Коты против собак,  лохматий спецназ]
# 1112                                              [Много]
# 1113                                      [Атака титанов]
# 1114                                 [Вам лучше не знать]
# 1115    [Месть/Возмездие/Revenge,  Теория лжи/Обмани м...
# 1116    ["Бунт ушастых",  "Конфу панда",  "Король лев"...
# 1117                                           [С бухлом]
# 1118                                          [Молодежка]
# 1119        [троя,  деточки,  гладиатор,  великий Гэтсби]
# dtype: object

# %%
um = get_unique_movies(b)

# %%
um
# Out:
# 0                            12 Angry Men
# 1                          "Зеленая миля"
# 2                         "Инопланетянин"
# 3               "Искусственный интеллект"
# 4                     "Осень в Нью-Йорке"
# 5                        "Ванильное небо"
# 6                         "Жестокие игры"
# 7                "Пираты Карибского моря"
# 8                           "Игры Разума"
# 9                               "Догвиль"
# 10                 "Достучаться до небес"
# 11                        "Особое мнение"
# 12                          "Эквилибриум"
# 13                              "Генезис"
# 14                    "Последний самурай"
# 15                    "Завтрак у Тиффани"
# 16                    "Водитель для Веры"
# 17                                "Майкл"
# 18                               "Клетка"
# 19                          "Война миров"
# 20         "Пролетая над гнездом кукушки"
# 21                       "Четыре комнаты"
# 22                    "Побег из Шоушенка"
# 23                                "Эдвард
# 24                          руки-ножницы"
# 25                       "Молчание ягнят"
# 26                                 "Семь"
# 27                      "Список Шиндлера"
# 28                      "Мой лучший друг"
# 29                               "Фонтан"
#                       ...
# 9148                          эквилибриум
# 9149                  искусственный разум
# 9150                   200 летний человек
# 9151                 достучаться до небес
# 9152                      бойцовский клуб
# 9153                                 ХАУС
# 9154                                побег
# 9155             как я встретил вашу маму
# 9156               теория большого взрыва
# 9157                   криминальное чтиво
# 9158                   Которые понравятся
# 9159                   Вам лучше не знать
# 9160                    Коты против собак
# 9161                     лохматий спецназ
# 9162                                Много
# 9163                        Атака титанов
# 9164                   Вам лучше не знать
# 9165              Месть/Возмездие/Revenge
# 9166     Теория лжи/Обмани меня/Lie to me
# 9167                       "Бунт ушастых"
# 9168                        "Конфу панда"
# 9169                         "Король лев"
# 9170                              "Шрек 1
# 9171                                2..."
# 9172                             С бухлом
# 9173                            Молодежка
# 9174                                 троя
# 9175                              деточки
# 9176                            гладиатор
# 9177                       великий Гэтсби
# dtype: object

# %%
mat = construct_matrix(b, um)
