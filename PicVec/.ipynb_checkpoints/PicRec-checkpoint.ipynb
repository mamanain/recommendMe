# %%
from theano import tensor as T
import theano
import lasagne
import PIL
import numpy as np
import os
from IPython.display import Image, display
from matplotlib import pyplot as plt
import sys
# %matplotlib inline

# %%
def memory_iter(path_name, batch_size=100):
    file_list = np.array(os.listdir(path_name))
    path_name = path_name.strip("/")
    for start_idx in range(0, len(file_list)-batch_size+1, batch_size):
        data = []
        ids = []
        for file in file_list[start_idx:start_idx+batch_size]:
            pic = np.array(PIL.Image.open("{0}/{1}".format(path_name, file)))
            if pic.shape == (100,100) :
                data.append(np.array([pic[:,:], pic[:,:], pic[:,:]]))
            else:
                data.append(np.array([pic[:,:,0], pic[:,:,1], pic[:,:,2]]))
            ids.append(file.split(".")[0])
        yield np.array(data), np.array(ids)

# %%
input_X = T.tensor4("Inputs")

# %%
######### First net 
######### Loss ~ 1800
input_layer = lasagne.layers.InputLayer((None, 3, 100, 100), input_X)

first_d = lasagne.layers.DenseLayer(input_layer, 500)
second_d = lasagne.layers.DenseLayer(first_d, 250)

vector_layer = lasagne.layers.DenseLayer(second_d, 100)

third_d = lasagne.layers.DenseLayer(vector_layer, 250)
fourth_d = lasagne.layers.DenseLayer(third_d, 500)

output = lasagne.layers.DenseLayer(fourth_d, 100*100)
final = lasagne.layers.ReshapeLayer(output, [[0], 1, 100, 100])

# %%
######## Second net
######## Loss ~ 2000
#input_layer = lasagne.layers.InputLayer((None, 3, 100, 100), input_X)

#d_1 = lasagne.layers.DenseLayer(input_layer, 500)
#d_2 = lasagne.layers.DenseLayer(d_1, 250)
#d_3 = lasagne.layers.DenseLayer(d_2, 150)

#vector_layer = lasagne.layers.DenseLayer(d_3, 100)

#d_4 = lasagne.layers.DenseLayer(vector_layer, 150)
#d_5 = lasagne.layers.DenseLayer(d_4, 250)
#d_6 = lasagne.layers.DenseLayer(d_5, 500)

#output = lasagne.layers.DenseLayer(d_6, 100*100)
#final = lasagne.layers.ReshapeLayer(output, [[0], 1, 100, 100])

# %%
restored = lasagne.layers.get_output(final)
weigths = lasagne.layers.get_all_params(final)

loss = lasagne.objectives.squared_error(input_X, restored).mean()
updates = lasagne.updates.adam(loss, weigths)

vector = lasagne.layers.get_output(vector_layer)

# %%
train_func = theano.function([input_X], [loss], updates=updates)
predict_func = theano.function([input_X], [restored])
vector_func = theano.function([input_X], [vector])

# %%
EPOCH = 150

for epoch in range(EPOCH):
    loss = 0
    counter = 0
    for X in memory_iter("../Images/", 100):
        
        loss += train_func(X)[0]
        counter += 1
    print("Epoch:{0} Loss:{1}".format(epoch, loss/counter))
# Out:
# Epoch:0 Loss:79515.680843004
# Epoch:1 Loss:5211.276042926608
# Epoch:2 Loss:4283.0041212332535
# Epoch:3 Loss:4052.0224147649124
# Epoch:4 Loss:3792.408859285366
# Epoch:5 Loss:13699.71903948604
# Epoch:6 Loss:14699.804965234855
# Epoch:7 Loss:4242.026448183389
# Epoch:8 Loss:3588.70628582779
# Epoch:9 Loss:3442.1411192345927
# Epoch:10 Loss:3357.481622778946
# Epoch:11 Loss:3277.11821194766
# Epoch:12 Loss:3199.469179166015
# Epoch:13 Loss:3122.805240722833
# Epoch:14 Loss:3053.090180288103
# Epoch:15 Loss:2999.6702024719593
# Epoch:16 Loss:2959.885927842749
# Epoch:17 Loss:2925.6004948337777
# Epoch:18 Loss:2892.5745644170547
# Epoch:19 Loss:2858.884770788747
# Epoch:20 Loss:2825.59834589726
# Epoch:21 Loss:2793.8917542003505
# Epoch:22 Loss:2762.3950613286606
# Epoch:23 Loss:2733.487464119129
# Epoch:24 Loss:2704.09276873303
# Epoch:25 Loss:2675.908096145771
# Epoch:26 Loss:2684.77569326594
# Epoch:27 Loss:2639.5385785846097
# Epoch:28 Loss:2579.3715631343575
# Epoch:29 Loss:2545.761951580695
# Epoch:30 Loss:2517.2972541501904
# Epoch:31 Loss:2497.283639514305
# Epoch:32 Loss:2479.5885077447274
# Epoch:33 Loss:2466.9153205881703
# Epoch:34 Loss:2425.5704374004576
# Epoch:35 Loss:2407.271548876257
# Epoch:36 Loss:2411.720911457582
# Epoch:37 Loss:2377.4722497134267
# Epoch:38 Loss:2357.582370662942
# Epoch:39 Loss:2376.463167218718
# Epoch:40 Loss:2393.3412516845383
# Epoch:41 Loss:2321.7146927624494
# Epoch:42 Loss:2310.8480715371493
# Epoch:43 Loss:2304.9946014423376
# Epoch:44 Loss:2286.371428820575
# Epoch:45 Loss:2279.21436975197
# Epoch:46 Loss:2268.4288644735784
# Epoch:47 Loss:2264.809534232315
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-136-e0e46b5a7fc0> in <module>()
#       6     for X in memory_iter("Images/", 100):
#       7
# ----> 8         loss += train_func(X)[0]
#       9         counter += 1
#      10     print("Epoch:{0} Loss:{1}".format(epoch, loss/counter))
#
# /home/mdm/anaconda3/lib/python3.5/site-packages/theano/compile/function_module.py in __call__(self, *args, **kwargs)
#     871         try:
#     872             outputs =\
# --> 873                 self.fn() if output_subset is None else\
#     874                 self.fn(output_subset=output_subset)
#     875         except Exception:
#
# KeyboardInterrupt:

# %%
lasagne.layers.set_all_param_values(final, np.load("Weights/first_weights.npy"))

# %%
data = []
pics = []
for file in os.listdir("Test_Images/"):
    pic = np.array(PIL.Image.open("Test_Images/{0}".format(file)))
    pics.append(pic)
    data.append(np.array([pic[:,:,0], pic[:,:,1], pic[:,:,2]]))
    
data = np.array(data)
pics = np.array(pics)

prediction = predict_func(data)

f, arr = plt.subplots(nrows=len(prediction[0]), ncols=2, figsize=(15,15))

for ind, pic in enumerate(prediction[0]):
    arr[ind][0].imshow(pics[ind])
    arr[ind][1].imshow(pic[0])

# %%
params = np.array(lasagne.layers.get_all_param_values(final))

# %%
params.dump("Weights/second_weights.npy")

# %% [markdown]
# ## Recommendation

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
for images, ids in memory_iter("../Images/", 300):
    vectors = vector_func(images)[0]
    for ind, vector in enumerate(vectors):
        vector.dump("../Vectors/{0}.vec".format(ids[ind]))

# %%
test_pic_orig = np.array(PIL.Image.open("Test_Images/3.jpg"))
test_pic = np.array([test_pic_orig[:,:,0], test_pic_orig[:,:,1], test_pic_orig[:,:,1]])
test_vec = vector_func([test_pic])[0][0]
plt.imshow(test_pic_orig)

# %%
data = []
users = {}
for ind, vec_name in enumerate(os.listdir("../Vectors/")):
    data.append(np.load("../Vectors/{0}".format(vec_name)))
    users[ind] = vec_name.split(".")[0]
data = np.array(data)

# %%
sims = cosine_similarity(test_vec, data)[0]
sim_dict = {y:users[x] for x,y in enumerate(sims)}
sims = sorted(sims, reverse=True)
# Out:
# /home/mdm/anaconda3/lib/python3.5/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)

# %%
images = []
for sim in sims[:10]:
    images.append(PIL.Image.open("../Images/{0}.png".format(sim_dict[sim])))
f, arr = plt.subplots(nrows=10, figsize=(50,50))
for i in range(10):
    arr[i].imshow(images[i])
